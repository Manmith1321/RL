# %% [markdown]
# <a href="https://colab.research.google.com/github/Manmith1321/RL/blob/main/PRACTICAL_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import gymnasium as gym

def random_agent(env_name, episodes=5):
    env = gym.make(env_name)

    for episode in range(1, episodes + 1):
        state, info = env.reset()
        total_reward = 0
        steps = 0
        terminated = False
        truncated = False

        while not (terminated or truncated):
            action = env.action_space.sample()
            next_state, reward, terminated, truncated, info = env.step(action)

            total_reward += reward
            steps += 1
            state = next_state

        average_reward = total_reward / steps

        print("Episode:", episode)
        print("Total Reward:", total_reward)
        print("Average Reward:", round(average_reward, 2))
        print()

    env.close()

print("CliffWalking Environment")
random_agent("CliffWalking-v1", 5)

print("Taxi Environment")
random_agent("Taxi-v4", 5)
# Out:
# CliffWalking Environment
# Episode: 1
# Total Reward: -47220
# Average Reward: -10.15
#
# Episode: 2
# Total Reward: -5995
# Average Reward: -10.9
#
# Episode: 3
# Total Reward: -123707
# Average Reward: -9.57
#
# Episode: 4
# Total Reward: -141890
# Average Reward: -10.22
#
# Episode: 5
# Total Reward: -189970
# Average Reward: -10.38
#
# Taxi Environment
# Episode: 1
# Total Reward: -731
# Average Reward: -3.65
#
# Episode: 2
# Total Reward: -767
# Average Reward: -3.83
#
# Episode: 3
# Total Reward: -776
# Average Reward: -3.88
#
# Episode: 4
# Total Reward: -812
# Average Reward: -4.06
#
# Episode: 5
# Total Reward: -749
# Average Reward: -3.75
