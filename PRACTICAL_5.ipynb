# %% [markdown]
# <a href="https://colab.research.google.com/github/Manmith1321/RL/blob/main/PRACTICAL_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import gymnasium as gym


def random_agent(env_name, episodes=5):

    env = gym.make(env_name)

    rewards = []

    print("\n==============================")
    print("Environment:", env_name)
    print("==============================")

    for episode in range(episodes):

        state, info = env.reset()

        total_reward = 0
        steps = 0

        terminated = False
        truncated = False

        while not (terminated or truncated):

            # Select random action
            action = env.action_space.sample()

            # Perform action
            next_state, reward, terminated, truncated, info = env.step(action)

            # Add reward
            total_reward += reward

            # Update state
            state = next_state

            steps += 1

        rewards.append(total_reward)

        print(
            "Episode", episode + 1,
            "| Steps:", steps,
            "| Total Reward:", total_reward
        )

    average_reward = sum(rewards) / len(rewards)

    print("------------------------------")
    print("Rewards:", rewards)
    print("Average Reward:", average_reward)

    env.close()


# Run environments
random_agent("CartPole-v1", 5)
random_agent("MountainCar-v0", 5)
random_agent("FrozenLake-v1", 5)
# Out:
# ...
# Environment: CartPole-v1
# ...
# Episode 1 | Steps: 20 | Total Reward: 20.0
# Episode 2 | Steps: 66 | Total Reward: 66.0
# Episode 3 | Steps: 36 | Total Reward: 36.0
# Episode 4 | Steps: 15 | Total Reward: 15.0
# Episode 5 | Steps: 42 | Total Reward: 42.0
# ------------------------------
# Rewards: [20.0, 66.0, 36.0, 15.0, 42.0]
# Average Reward: 35.8
#
# ...
# Environment: MountainCar-v0
# ...
# Episode 1 | Steps: 200 | Total Reward: -200.0
# Episode 2 | Steps: 200 | Total Reward: -200.0
# Episode 3 | Steps: 200 | Total Reward: -200.0
# Episode 4 | Steps: 200 | Total Reward: -200.0
# Episode 5 | Steps: 200 | Total Reward: -200.0
# ------------------------------
# Rewards: [-200.0, -200.0, -200.0, -200.0, -200.0]
# Average Reward: -200.0
#
# ...
# Environment: FrozenLake-v1
# ...
# Episode 1 | Steps: 3 | Total Reward: 0
# Episode 2 | Steps: 4 | Total Reward: 0
# Episode 3 | Steps: 2 | Total Reward: 0
# Episode 4 | Steps: 6 | Total Reward: 0
# Episode 5 | Steps: 3 | Total Reward: 0
# ...
